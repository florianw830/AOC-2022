# %%
from  concurrent.futures import ThreadPoolExecutor
from concurrent.futures import as_completed
import threading

f = open("input.txt", "r")
l = f.read().split("\n")[:-1]
#print(l)
lock = threading.RLock()
ctl = 0

# %%
class MyScanner:
    def __init__(self,x,y,beaconX,beaconY):
        self.x = x
        self.y = y
        self.beaconX = beaconX
        self.beaconY = beaconY
        self.m = self.getManhatten()
    def getManhatten(self):
        return abs(self.x -self.beaconX) + abs(self.y -self.beaconY)
    def manhattenAt(self,y):
        ret = []
        #print(self.x,self.y)
        #print(self.y + self.m,y)
        #print(self.y-self.m,y)
        
        if (self.y + self.m >= y and self.y <=y) or (self.y-self.m <= y and  self.y >= y):
            tmpM = 1+self.m-abs(self.y- y)
            
            for x in range(-tmpM+1,0):
                ret.append(self.x+x)
            for x in range(0,tmpM):
                ret.append(self.x+x)
            
        return list(sorted(list(set(ret))))

    def manhattenAt2(self,y):
        ret = []
        #print(self.x,self.y)
        #print(self.y + self.m,y)
        #print(self.y-self.m,y)
        
        if (self.y + self.m >= y and self.y <=y) or (self.y-self.m <= y and  self.y >= y):
            tmpM = 1+self.m-abs(self.y- y)
            #print("position",self.x,self.y)
            #print("target",self.x,y)
            #print("manhatten full", self.m)
            #print("manhatten to point", abs(self.y- y))
            #print("pointsLeft", tmpM)

            ret = [-tmpM+1+self.x,tmpM-1+self.x]


        return ret

# %%
maxX = 0
minX = 0
sensorList = []
for s in l:
    
    _x = int(s.split(" ")[2].split("=")[1][:-1])
    if _x > maxX:
        maxX = _x
    if _x <minX:
        minX = _x
        
    _y = int(s.split(" ")[3].split("=")[1][:-1])
    _bx = int(s.split(" ")[8].split("=")[1][:-1])
    _by = int(s.split(" ")[9].split("=")[1])
    #print(_x,_y,_bx,_by)
    tmp = MyScanner(_x,_y,_bx,_by)
    #print(tmp.m, s)
    sensorList.append(tmp)
line = []


    
def containsFull(a,b,p):
    if a[0]>=b[0] and a[1]<=b[1]:
        #if p: print("CF",b,a)
        return True
    return False

def lContainsFull(a,l,p):
    for x in l:
        if containsFull(a,x,p):
            return True
    return False

# %%
for y in range(0,4000001):
    if y % 100000==0:
        print(y)
    line  =[]
    for s in sensorList:
        r = s.manhattenAt2(y)
        if r != []:
            line.append(r)

    line2 = []

    for i in range(0,len(line)):
        if not lContainsFull(line[i],line[0:i]+line[i+1:],True):
            line2.append(line[i])


    line2.sort(key=lambda a: a[0])
    
    ct=0
    cct = 0

    
    for i in range(0,len(line2)-1):
        if not line2[i][1]>=line2[i+1][0] and not line2[i][1]+1==line2[i+1][0]:
            print("match:",4000000*(line2[i][1]+1)+y)
            break
# Out:
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# 1200000
# 1300000
# 1400000
# 1500000
# 1600000
# 1700000
# 1800000
# 1900000
# 2000000
# 2100000
# 2200000
# 2300000
# 2400000
# 2500000
# 2600000
# 2700000
# 2800000
# 2900000
# 3000000
# 3100000
# 3200000
# match: 13622251246513
# 3300000
# 3400000
# 3500000
# 3600000
# 3700000
# 3800000
# 3900000
# 4000000
